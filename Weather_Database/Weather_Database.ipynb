# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = lat_lngs

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 784

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from my_config import my_weather_api_key as key

# %%
# Assemble the OpenWeatherMap's API call
units = "imperial"
url = "https://api.openweathermap.org/data/2.5/weather"

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "?q=" + city.replace(" ","+") + "&appid=" + key + "&units=" + units
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lon = city_weather["coord"]["lon"]
        city_maxtemp = city_weather["main"]["temp_max"]
        city_hum = city_weather["main"]["humidity"]
        city_cloud = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_wedescr = city_weather["weather"][0]["description"]     
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lon": city_lon,
                            "Max Temp": city_maxtemp,
                            "Humidity": city_hum,
                            "Cloudiness": city_cloud,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Current Description": city_wedescr.title()})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amahai
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | hambantota
# Processing Record 4 of Set 1 | torbay
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | sao sebastiao
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | salalah
# Processing Record 9 of Set 1 | fortuna foothills
# Processing Record 10 of Set 1 | deputatskiy
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | mount isa
# Processing Record 13 of Set 1 | sao gabriel da cachoeira
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | aden
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | sisimiut
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | college
# Processing Record 25 of Set 1 | santa cruz do capibaribe
# Processing Record 26 of Set 1 | le pradet
# Processing Record 27 of Set 1 | dingle
# Processing Record 28 of Set 1 | sao filipe
# Processing Record 29 of Set 1 | toccoa
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | pangnirtung
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | san patricio
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | green valley
# Processing Record 37 of Set 1 | sarkand
# Processing Record 38 of Set 1 | mahebourg
# Processing Record 39 of Set 1 | manali
# Processing Record 40 of Set 1 | egvekinot
# Processing Record 41 of Set 1 | kavieng
# Processing Record 42 of Set 1 | pevek
# Processing Record 43 of Set 1 | alofi
# Processing Record 44 of Set 1 | vreed en hoop
# City not found. Skipping...
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | odweyne
# Processing Record 47 of Set 1 | benito juarez
# Processing Record 48 of Set 1 | khatanga
# Processing Record 49 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 1 | tefe
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | hami
# Processing Record 4 of Set 2 | karasburg
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | touros
# Processing Record 7 of Set 2 | muli
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | port alfred
# Processing Record 10 of Set 2 | mayya
# Processing Record 11 of Set 2 | kudahuvadhoo
# Processing Record 12 of Set 2 | thompson
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | kifri
# Processing Record 15 of Set 2 | iqaluit
# Processing Record 16 of Set 2 | naze
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | port hardy
# Processing Record 19 of Set 2 | alice springs
# Processing Record 20 of Set 2 | tura
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | butaritari
# Processing Record 23 of Set 2 | luang prabang
# Processing Record 24 of Set 2 | bardiyah
# Processing Record 25 of Set 2 | cabo san lucas
# Processing Record 26 of Set 2 | fortuna
# Processing Record 27 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | geraldton
# Processing Record 30 of Set 2 | okhotsk
# Processing Record 31 of Set 2 | lagoa
# Processing Record 32 of Set 2 | guerrero negro
# Processing Record 33 of Set 2 | adre
# Processing Record 34 of Set 2 | heilbron
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | sungaipenuh
# Processing Record 37 of Set 2 | souillac
# Processing Record 38 of Set 2 | pinyug
# Processing Record 39 of Set 2 | elban
# Processing Record 40 of Set 2 | chokurdakh
# Processing Record 41 of Set 2 | inta
# Processing Record 42 of Set 2 | mount gambier
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | haines junction
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | rafaela
# Processing Record 47 of Set 2 | port blair
# Processing Record 48 of Set 2 | trincomalee
# Processing Record 49 of Set 2 | sioux lookout
# Processing Record 50 of Set 2 | veracruz
# Processing Record 1 of Set 3 | rio cuarto
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 3 | ponta do sol
# Processing Record 4 of Set 3 | ambilobe
# Processing Record 5 of Set 3 | taoudenni
# Processing Record 6 of Set 3 | asau
# Processing Record 7 of Set 3 | hilo
# Processing Record 8 of Set 3 | soweto
# Processing Record 9 of Set 3 | gat
# Processing Record 10 of Set 3 | makakilo city
# Processing Record 11 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 3 | opuwo
# Processing Record 13 of Set 3 | palmer
# Processing Record 14 of Set 3 | sao bernardo
# Processing Record 15 of Set 3 | bubaque
# Processing Record 16 of Set 3 | novaya igirma
# Processing Record 17 of Set 3 | rikitea
# Processing Record 18 of Set 3 | norman wells
# Processing Record 19 of Set 3 | labuhan
# Processing Record 20 of Set 3 | hualmay
# Processing Record 21 of Set 3 | namatanai
# Processing Record 22 of Set 3 | ancud
# Processing Record 23 of Set 3 | padang
# Processing Record 24 of Set 3 | severo-kurilsk
# Processing Record 25 of Set 3 | northam
# Processing Record 26 of Set 3 | saint-joseph
# Processing Record 27 of Set 3 | lubango
# Processing Record 28 of Set 3 | umm lajj
# Processing Record 29 of Set 3 | san cristobal
# Processing Record 30 of Set 3 | barrow
# Processing Record 31 of Set 3 | otane
# Processing Record 32 of Set 3 | saskylakh
# Processing Record 33 of Set 3 | vila franca do campo
# Processing Record 34 of Set 3 | clyde river
# Processing Record 35 of Set 3 | kaitangata
# Processing Record 36 of Set 3 | wuda
# Processing Record 37 of Set 3 | baykit
# Processing Record 38 of Set 3 | bambous virieux
# Processing Record 39 of Set 3 | cairns
# Processing Record 40 of Set 3 | harboore
# Processing Record 41 of Set 3 | muisne
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | jalu
# Processing Record 44 of Set 3 | bratsk
# Processing Record 45 of Set 3 | saint-augustin
# Processing Record 46 of Set 3 | bend
# Processing Record 47 of Set 3 | husavik
# Processing Record 48 of Set 3 | broken hill
# Processing Record 49 of Set 3 | paamiut
# Processing Record 50 of Set 3 | tabuk
# Processing Record 1 of Set 4 | kruisfontein
# Processing Record 2 of Set 4 | flin flon
# Processing Record 3 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 4 | yulara
# Processing Record 5 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 4 | half moon bay
# Processing Record 8 of Set 4 | talcahuano
# Processing Record 9 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 4 | erenhot
# Processing Record 11 of Set 4 | marsh harbour
# Processing Record 12 of Set 4 | montepuez
# Processing Record 13 of Set 4 | denpasar
# Processing Record 14 of Set 4 | zhigansk
# Processing Record 15 of Set 4 | coquimbo
# Processing Record 16 of Set 4 | maceio
# Processing Record 17 of Set 4 | naifaru
# Processing Record 18 of Set 4 | victoria
# Processing Record 19 of Set 4 | jijiga
# Processing Record 20 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 4 | slave lake
# Processing Record 23 of Set 4 | wajima
# Processing Record 24 of Set 4 | nikolskoye
# Processing Record 25 of Set 4 | winneba
# Processing Record 26 of Set 4 | kajaani
# Processing Record 27 of Set 4 | savannah bight
# Processing Record 28 of Set 4 | tabou
# Processing Record 29 of Set 4 | mollendo
# Processing Record 30 of Set 4 | sarti
# Processing Record 31 of Set 4 | olinda
# Processing Record 32 of Set 4 | faya
# Processing Record 33 of Set 4 | kungurtug
# Processing Record 34 of Set 4 | taman
# Processing Record 35 of Set 4 | kidal
# Processing Record 36 of Set 4 | bilma
# Processing Record 37 of Set 4 | saldanha
# Processing Record 38 of Set 4 | tasiilaq
# Processing Record 39 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 4 | narsaq
# Processing Record 41 of Set 4 | bethel
# Processing Record 42 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 43 of Set 4 | avera
# Processing Record 44 of Set 4 | lebu
# Processing Record 45 of Set 4 | srednekolymsk
# Processing Record 46 of Set 4 | mehamn
# Processing Record 47 of Set 4 | plouzane
# Processing Record 48 of Set 4 | tokonou
# Processing Record 49 of Set 4 | mwense
# Processing Record 50 of Set 4 | sundargarh
# Processing Record 1 of Set 5 | sovetskiy
# Processing Record 2 of Set 5 | inhambane
# Processing Record 3 of Set 5 | uusikaupunki
# Processing Record 4 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 5 of Set 5 | araouane
# Processing Record 6 of Set 5 | porto novo
# Processing Record 7 of Set 5 | tual
# Processing Record 8 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 5 | havre-saint-pierre
# Processing Record 10 of Set 5 | morro bay
# Processing Record 11 of Set 5 | ust-omchug
# Processing Record 12 of Set 5 | bluff
# Processing Record 13 of Set 5 | telde
# Processing Record 14 of Set 5 | taga
# Processing Record 15 of Set 5 | san juan
# Processing Record 16 of Set 5 | talpa
# Processing Record 17 of Set 5 | xining
# Processing Record 18 of Set 5 | grand gaube
# Processing Record 19 of Set 5 | kilindoni
# Processing Record 20 of Set 5 | itarema
# Processing Record 21 of Set 5 | shenjiamen
# Processing Record 22 of Set 5 | upernavik
# Processing Record 23 of Set 5 | teresina
# Processing Record 24 of Set 5 | praya
# Processing Record 25 of Set 5 | hendijan
# City not found. Skipping...
# Processing Record 26 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 5 | nzega
# Processing Record 28 of Set 5 | saint george
# Processing Record 29 of Set 5 | palmares do sul
# Processing Record 30 of Set 5 | helong
# Processing Record 31 of Set 5 | breytovo
# Processing Record 32 of Set 5 | pandaria
# Processing Record 33 of Set 5 | campos belos
# Processing Record 34 of Set 5 | jamestown
# Processing Record 35 of Set 5 | taltal
# Processing Record 36 of Set 5 | santa fe
# Processing Record 37 of Set 5 | omboue
# Processing Record 38 of Set 5 | lasa
# Processing Record 39 of Set 5 | chulman
# Processing Record 40 of Set 5 | islamnagar
# Processing Record 41 of Set 5 | isla mujeres
# Processing Record 42 of Set 5 | eenhana
# Processing Record 43 of Set 5 | ilheus
# Processing Record 44 of Set 5 | pakwach
# City not found. Skipping...
# Processing Record 45 of Set 5 | kiama
# Processing Record 46 of Set 5 | uglovskoye
# Processing Record 47 of Set 5 | porto velho
# Processing Record 48 of Set 5 | hamilton
# Processing Record 49 of Set 5 | mogadishu
# Processing Record 50 of Set 5 | waddan
# Processing Record 1 of Set 6 | frontera
# Processing Record 2 of Set 6 | natal
# Processing Record 3 of Set 6 | vestmannaeyjar
# Processing Record 4 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 6 | codrington
# Processing Record 6 of Set 6 | evensk
# Processing Record 7 of Set 6 | waingapu
# Processing Record 8 of Set 6 | cherskiy
# Processing Record 9 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 6 | huarmey
# Processing Record 11 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 6 | kyra
# Processing Record 13 of Set 6 | high rock
# Processing Record 14 of Set 6 | moju
# Processing Record 15 of Set 6 | tanout
# Processing Record 16 of Set 6 | kathu
# Processing Record 17 of Set 6 | dikson
# Processing Record 18 of Set 6 | coihueco
# Processing Record 19 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 6 | zyryanka
# Processing Record 21 of Set 6 | rocha
# Processing Record 22 of Set 6 | jagdalpur
# Processing Record 23 of Set 6 | port elizabeth
# Processing Record 24 of Set 6 | te anau
# Processing Record 25 of Set 6 | vung tau
# Processing Record 26 of Set 6 | sorland
# Processing Record 27 of Set 6 | monywa
# Processing Record 28 of Set 6 | obo
# Processing Record 29 of Set 6 | cockburn town
# Processing Record 30 of Set 6 | fredericksburg
# Processing Record 31 of Set 6 | port-cartier
# Processing Record 32 of Set 6 | cornwall
# Processing Record 33 of Set 6 | karlskoga
# Processing Record 34 of Set 6 | moron
# Processing Record 35 of Set 6 | tapaua
# City not found. Skipping...
# Processing Record 36 of Set 6 | mayor pablo lagerenza
# Processing Record 37 of Set 6 | tecoanapa
# Processing Record 38 of Set 6 | meulaboh
# Processing Record 39 of Set 6 | kitoy
# Processing Record 40 of Set 6 | fare
# Processing Record 41 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 6 | berbera
# Processing Record 43 of Set 6 | chuy
# Processing Record 44 of Set 6 | joshimath
# Processing Record 45 of Set 6 | tazovskiy
# Processing Record 46 of Set 6 | brora
# Processing Record 47 of Set 6 | gull lake
# Processing Record 48 of Set 6 | arraial do cabo
# Processing Record 49 of Set 6 | ola
# Processing Record 50 of Set 6 | carahue
# Processing Record 1 of Set 7 | aasiaat
# Processing Record 2 of Set 7 | chumikan
# Processing Record 3 of Set 7 | illela
# Processing Record 4 of Set 7 | ribeira grande
# Processing Record 5 of Set 7 | hasaki
# Processing Record 6 of Set 7 | masty
# Processing Record 7 of Set 7 | leningradskiy
# Processing Record 8 of Set 7 | safaqis
# City not found. Skipping...
# Processing Record 9 of Set 7 | weiser
# Processing Record 10 of Set 7 | menongue
# Processing Record 11 of Set 7 | khonsa
# Processing Record 12 of Set 7 | walvis bay
# Processing Record 13 of Set 7 | felidhoo
# City not found. Skipping...
# Processing Record 14 of Set 7 | carnarvon
# Processing Record 15 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 7 | ilulissat
# Processing Record 17 of Set 7 | camopi
# Processing Record 18 of Set 7 | chimoio
# Processing Record 19 of Set 7 | luderitz
# Processing Record 20 of Set 7 | puerto del rosario
# Processing Record 21 of Set 7 | dianopolis
# City not found. Skipping...
# Processing Record 22 of Set 7 | esperance
# Processing Record 23 of Set 7 | polson
# Processing Record 24 of Set 7 | sur
# Processing Record 25 of Set 7 | kodiak
# Processing Record 26 of Set 7 | airai
# Processing Record 27 of Set 7 | saint-louis
# Processing Record 28 of Set 7 | gulu
# Processing Record 29 of Set 7 | yarensk
# Processing Record 30 of Set 7 | taicheng
# Processing Record 31 of Set 7 | roebourne
# Processing Record 32 of Set 7 | presidencia roque saenz pena
# Processing Record 33 of Set 7 | balikpapan
# Processing Record 34 of Set 7 | jacksonville
# Processing Record 35 of Set 7 | warrenton
# Processing Record 36 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 7 | khingansk
# Processing Record 38 of Set 7 | longyearbyen
# Processing Record 39 of Set 7 | manturovo
# Processing Record 40 of Set 7 | shupiyan
# Processing Record 41 of Set 7 | port lincoln
# Processing Record 42 of Set 7 | waipawa
# Processing Record 43 of Set 7 | nelson bay
# Processing Record 44 of Set 7 | lincoln
# Processing Record 45 of Set 7 | talnakh
# Processing Record 46 of Set 7 | kitimat
# Processing Record 47 of Set 7 | nouadhibou
# Processing Record 48 of Set 7 | cabra
# Processing Record 49 of Set 7 | xam nua
# Processing Record 50 of Set 7 | atambua
# Processing Record 1 of Set 8 | donskoye
# Processing Record 2 of Set 8 | pontes e lacerda
# Processing Record 3 of Set 8 | ostrovnoy
# Processing Record 4 of Set 8 | del rio
# Processing Record 5 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 6 of Set 8 | anderson
# Processing Record 7 of Set 8 | grand falls
# Processing Record 8 of Set 8 | dryden
# Processing Record 9 of Set 8 | isangel
# Processing Record 10 of Set 8 | kihei
# Processing Record 11 of Set 8 | port keats
# Processing Record 12 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 13 of Set 8 | mount pleasant
# Processing Record 14 of Set 8 | bara
# Processing Record 15 of Set 8 | atar
# Processing Record 16 of Set 8 | kavaratti
# Processing Record 17 of Set 8 | kharan
# Processing Record 18 of Set 8 | salinas
# Processing Record 19 of Set 8 | parrita
# Processing Record 20 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 21 of Set 8 | mitu
# Processing Record 22 of Set 8 | yeppoon
# Processing Record 23 of Set 8 | platanos
# Processing Record 24 of Set 8 | saint-pierre
# Processing Record 25 of Set 8 | bahia honda
# Processing Record 26 of Set 8 | majene
# Processing Record 27 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 8 | celestun
# Processing Record 29 of Set 8 | zhangjiakou
# Processing Record 30 of Set 8 | severnyy
# Processing Record 31 of Set 8 | sicamous
# Processing Record 32 of Set 8 | olafsvik
# Processing Record 33 of Set 8 | kahului
# Processing Record 34 of Set 8 | coelho neto
# Processing Record 35 of Set 8 | tautira
# Processing Record 36 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 37 of Set 8 | innisfail
# Processing Record 38 of Set 8 | constitucion
# Processing Record 39 of Set 8 | damghan
# Processing Record 40 of Set 8 | troitskoye
# Processing Record 41 of Set 8 | progreso
# Processing Record 42 of Set 8 | tuatapere
# Processing Record 43 of Set 8 | chabahar
# Processing Record 44 of Set 8 | lorengau
# Processing Record 45 of Set 8 | kasama
# Processing Record 46 of Set 8 | luckenwalde
# Processing Record 47 of Set 8 | ulaanbaatar
# Processing Record 48 of Set 8 | cayenne
# Processing Record 49 of Set 8 | pareora
# Processing Record 50 of Set 8 | catuday
# Processing Record 1 of Set 9 | bathsheba
# Processing Record 2 of Set 9 | sangar
# Processing Record 3 of Set 9 | san andres
# Processing Record 4 of Set 9 | kysyl-syr
# Processing Record 5 of Set 9 | flinders
# Processing Record 6 of Set 9 | kosino
# Processing Record 7 of Set 9 | general roca
# Processing Record 8 of Set 9 | aykhal
# Processing Record 9 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 10 of Set 9 | matsanga
# City not found. Skipping...
# Processing Record 11 of Set 9 | ambulu
# Processing Record 12 of Set 9 | henties bay
# Processing Record 13 of Set 9 | ozu
# Processing Record 14 of Set 9 | twentynine palms
# Processing Record 15 of Set 9 | lompoc
# Processing Record 16 of Set 9 | phun phin
# City not found. Skipping...
# Processing Record 17 of Set 9 | marawi
# Processing Record 18 of Set 9 | acapulco
# Processing Record 19 of Set 9 | gavrilovka vtoraya
# Processing Record 20 of Set 9 | necochea
# Processing Record 21 of Set 9 | klaksvik
# Processing Record 22 of Set 9 | vitim
# Processing Record 23 of Set 9 | pasighat
# Processing Record 24 of Set 9 | champerico
# Processing Record 25 of Set 9 | kitui
# Processing Record 26 of Set 9 | warrnambool
# Processing Record 27 of Set 9 | cidreira
# Processing Record 28 of Set 9 | torrelavega
# Processing Record 29 of Set 9 | north bend
# Processing Record 30 of Set 9 | vestmanna
# Processing Record 31 of Set 9 | mbandaka
# Processing Record 32 of Set 9 | yar-sale
# Processing Record 33 of Set 9 | ayorou
# Processing Record 34 of Set 9 | komsomolskiy
# Processing Record 35 of Set 9 | alcudia
# Processing Record 36 of Set 9 | pozo colorado
# Processing Record 37 of Set 9 | qasigiannguit
# Processing Record 38 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 39 of Set 9 | hay river
# Processing Record 40 of Set 9 | irklievskaya
# City not found. Skipping...
# Processing Record 41 of Set 9 | serdobsk
# Processing Record 42 of Set 9 | sitka
# Processing Record 43 of Set 9 | santiago de cao
# Processing Record 44 of Set 9 | tilichiki
# Processing Record 45 of Set 9 | port augusta
# Processing Record 46 of Set 9 | hovd
# Processing Record 47 of Set 9 | aklavik
# Processing Record 48 of Set 9 | broome
# Processing Record 49 of Set 9 | atikokan
# Processing Record 50 of Set 9 | kishapu
# Processing Record 1 of Set 10 | mattawa
# Processing Record 2 of Set 10 | bavly
# Processing Record 3 of Set 10 | cilegon
# Processing Record 4 of Set 10 | lexington
# Processing Record 5 of Set 10 | bocanda
# Processing Record 6 of Set 10 | kastamonu
# Processing Record 7 of Set 10 | andenes
# Processing Record 8 of Set 10 | bom jesus
# Processing Record 9 of Set 10 | stephenville
# Processing Record 10 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 11 of Set 10 | yumen
# Processing Record 12 of Set 10 | yambio
# Processing Record 13 of Set 10 | fort-shevchenko
# Processing Record 14 of Set 10 | bulawayo
# Processing Record 15 of Set 10 | juba
# Processing Record 16 of Set 10 | aborlan
# Processing Record 17 of Set 10 | loreto
# Processing Record 18 of Set 10 | nanortalik
# Processing Record 19 of Set 10 | faanui
# Processing Record 20 of Set 10 | vardo
# Processing Record 21 of Set 10 | nishihara
# Processing Record 22 of Set 10 | sarakhs
# Processing Record 23 of Set 10 | qianan
# Processing Record 24 of Set 10 | moro
# Processing Record 25 of Set 10 | chateauroux
# Processing Record 26 of Set 10 | castellammare del golfo
# Processing Record 27 of Set 10 | taraz
# Processing Record 28 of Set 10 | bozoum
# Processing Record 29 of Set 10 | dhone
# Processing Record 30 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 10 | moose factory
# Processing Record 32 of Set 10 | san quintin
# Processing Record 33 of Set 10 | mbaiki
# Processing Record 34 of Set 10 | ullal
# Processing Record 35 of Set 10 | amapa
# Processing Record 36 of Set 10 | saraland
# Processing Record 37 of Set 10 | rapid valley
# Processing Record 38 of Set 10 | roi et
# Processing Record 39 of Set 10 | tando adam
# Processing Record 40 of Set 10 | arandelovac
# City not found. Skipping...
# Processing Record 41 of Set 10 | bloomfield
# Processing Record 42 of Set 10 | waterloo
# Processing Record 43 of Set 10 | nongan
# Processing Record 44 of Set 10 | junction city
# Processing Record 45 of Set 10 | vostok
# Processing Record 46 of Set 10 | peace river
# Processing Record 47 of Set 10 | najran
# Processing Record 48 of Set 10 | valparaiso
# Processing Record 49 of Set 10 | santarem
# Processing Record 50 of Set 10 | utete
# Processing Record 1 of Set 11 | akyab
# Processing Record 2 of Set 11 | traverse city
# Processing Record 3 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 4 of Set 11 | kirakira
# Processing Record 5 of Set 11 | lavrentiya
# Processing Record 6 of Set 11 | caucasia
# Processing Record 7 of Set 11 | doha
# Processing Record 8 of Set 11 | mayskiy
# Processing Record 9 of Set 11 | huilong
# Processing Record 10 of Set 11 | bintulu
# Processing Record 11 of Set 11 | comodoro rivadavia
# Processing Record 12 of Set 11 | ossora
# Processing Record 13 of Set 11 | visby
# Processing Record 14 of Set 11 | puerto lopez
# Processing Record 15 of Set 11 | yangmei
# Processing Record 16 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 11 | sao desiderio
# Processing Record 19 of Set 11 | temiscaming
# Processing Record 20 of Set 11 | hervey bay
# Processing Record 21 of Set 11 | riverton
# Processing Record 22 of Set 11 | beloha
# Processing Record 23 of Set 11 | byron bay
# Processing Record 24 of Set 11 | xuanhua
# Processing Record 25 of Set 11 | verkhnevilyuysk
# Processing Record 26 of Set 11 | itaituba
# Processing Record 27 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 28 of Set 11 | kimbe
# Processing Record 29 of Set 11 | brae
# Processing Record 30 of Set 11 | pisco
# Processing Record 31 of Set 11 | goure
# Processing Record 32 of Set 11 | bathurst
# Processing Record 33 of Set 11 | nieuwpoort
# Processing Record 34 of Set 11 | nome
# Processing Record 35 of Set 11 | nador
# Processing Record 36 of Set 11 | beringovskiy
# Processing Record 37 of Set 11 | puerto madryn
# Processing Record 38 of Set 11 | buala
# Processing Record 39 of Set 11 | praia da vitoria
# Processing Record 40 of Set 11 | carutapera
# Processing Record 41 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 42 of Set 11 | frekhaug
# Processing Record 43 of Set 11 | grandview
# Processing Record 44 of Set 11 | caravelas
# Processing Record 45 of Set 11 | carballo
# Processing Record 46 of Set 11 | urshelskiy
# Processing Record 47 of Set 11 | kamaishi
# Processing Record 48 of Set 11 | miraflores
# Processing Record 49 of Set 11 | orlik
# Processing Record 50 of Set 11 | santa cruz cabralia
# Processing Record 1 of Set 12 | sipe sipe
# Processing Record 2 of Set 12 | barranca
# Processing Record 3 of Set 12 | coronel oviedo
# Processing Record 4 of Set 12 | zhoucheng
# Processing Record 5 of Set 12 | jurm
# Processing Record 6 of Set 12 | mangan
# Processing Record 7 of Set 12 | portland
# Processing Record 8 of Set 12 | graneros
# Processing Record 9 of Set 12 | williams lake
# Processing Record 10 of Set 12 | copiapo
# Processing Record 11 of Set 12 | jiuquan
# Processing Record 12 of Set 12 | kieta
# Processing Record 13 of Set 12 | la orilla
# Processing Record 14 of Set 12 | la tuque
# Processing Record 15 of Set 12 | paita
# Processing Record 16 of Set 12 | banes
# Processing Record 17 of Set 12 | codajas
# Processing Record 18 of Set 12 | mana
# Processing Record 19 of Set 12 | pascagoula
# Processing Record 20 of Set 12 | mumford
# Processing Record 21 of Set 12 | koslan
# Processing Record 22 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 12 | konstantinovka
# Processing Record 24 of Set 12 | mokhsogollokh
# Processing Record 25 of Set 12 | sao felix do xingu
# Processing Record 26 of Set 12 | nabire
# Processing Record 27 of Set 12 | polunochnoye
# Processing Record 28 of Set 12 | urbana
# Processing Record 29 of Set 12 | seoul
# Processing Record 30 of Set 12 | banda aceh
# Processing Record 31 of Set 12 | quetzaltepec
# City not found. Skipping...
# Processing Record 32 of Set 12 | katsuura
# Processing Record 33 of Set 12 | dongsheng
# Processing Record 34 of Set 12 | mikhaylovka
# Processing Record 35 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 36 of Set 12 | lensk
# Processing Record 37 of Set 12 | faridpur
# Processing Record 38 of Set 12 | aranos
# Processing Record 39 of Set 12 | caloundra
# Processing Record 40 of Set 12 | lubao
# Processing Record 41 of Set 12 | jamame
# Processing Record 42 of Set 12 | matamoros
# Processing Record 43 of Set 12 | pimentel
# Processing Record 44 of Set 12 | ewo
# Processing Record 45 of Set 12 | pandan
# Processing Record 46 of Set 12 | sampit
# Processing Record 47 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 12 | victor harbor
# Processing Record 49 of Set 12 | port macquarie
# Processing Record 50 of Set 12 | nacala
# Processing Record 1 of Set 13 | saint anthony
# Processing Record 2 of Set 13 | tiznit
# Processing Record 3 of Set 13 | nemuro
# Processing Record 4 of Set 13 | dhidhdhoo
# Processing Record 5 of Set 13 | xichang
# Processing Record 6 of Set 13 | christchurch
# Processing Record 7 of Set 13 | chama
# Processing Record 8 of Set 13 | zachagansk
# City not found. Skipping...
# Processing Record 9 of Set 13 | karratha
# Processing Record 10 of Set 13 | shinuhayr
# Processing Record 11 of Set 13 | margate
# Processing Record 12 of Set 13 | susehri
# Processing Record 13 of Set 13 | maracas
# Processing Record 14 of Set 13 | port-gentil
# Processing Record 15 of Set 13 | chaah
# Processing Record 16 of Set 13 | panzhihua
# Processing Record 17 of Set 13 | sawtell
# Processing Record 18 of Set 13 | coahuayana
# Processing Record 19 of Set 13 | tambo
# Processing Record 20 of Set 13 | poya
# Processing Record 21 of Set 13 | kemijarvi
# Processing Record 22 of Set 13 | udachnyy
# Processing Record 23 of Set 13 | honningsvag
# Processing Record 24 of Set 13 | merke
# Processing Record 25 of Set 13 | woodward
# Processing Record 26 of Set 13 | knyaginino
# Processing Record 27 of Set 13 | gamba
# Processing Record 28 of Set 13 | dakar
# Processing Record 29 of Set 13 | viedma
# Processing Record 30 of Set 13 | lata
# Processing Record 31 of Set 13 | maltahohe
# Processing Record 32 of Set 13 | kafue
# Processing Record 33 of Set 13 | koszalin
# Processing Record 34 of Set 13 | laguna
# Processing Record 35 of Set 13 | rosetta
# Processing Record 36 of Set 13 | maldonado
# Processing Record 37 of Set 13 | berdigestyakh
# Processing Record 38 of Set 13 | rafai
# Processing Record 39 of Set 13 | the pas
# Processing Record 40 of Set 13 | honiara
# Processing Record 41 of Set 13 | shelopugino
# Processing Record 42 of Set 13 | magadan
# Processing Record 43 of Set 13 | silao
# Processing Record 44 of Set 13 | xuddur
# Processing Record 45 of Set 13 | hammerfest
# Processing Record 46 of Set 13 | kindu
# Processing Record 47 of Set 13 | severobaykalsk
# Processing Record 48 of Set 13 | karasjok
# Processing Record 49 of Set 13 | beyneu
# Processing Record 50 of Set 13 | abulug
# Processing Record 1 of Set 14 | chandbali
# Processing Record 2 of Set 14 | nalhati
# Processing Record 3 of Set 14 | biak
# Processing Record 4 of Set 14 | elyakhin
# Processing Record 5 of Set 14 | pacific grove
# Processing Record 6 of Set 14 | jiamusi
# Processing Record 7 of Set 14 | solnechnyy
# Processing Record 8 of Set 14 | morondava
# Processing Record 9 of Set 14 | palm coast
# Processing Record 10 of Set 14 | anadyr
# Processing Record 11 of Set 14 | kazachinskoye
# Processing Record 12 of Set 14 | moss vale
# Processing Record 13 of Set 14 | la vega
# Processing Record 14 of Set 14 | harbour breton
# Processing Record 15 of Set 14 | changli
# Processing Record 16 of Set 14 | nizwa
# Processing Record 17 of Set 14 | eureka
# Processing Record 18 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 19 of Set 14 | fuzhou
# Processing Record 20 of Set 14 | caucaia
# Processing Record 21 of Set 14 | road town
# Processing Record 22 of Set 14 | minot
# Processing Record 23 of Set 14 | dondo
# Processing Record 24 of Set 14 | rio verde de mato grosso
# Processing Record 25 of Set 14 | guelengdeng
# City not found. Skipping...
# Processing Record 26 of Set 14 | havelock
# Processing Record 27 of Set 14 | verkhoshizhemye
# Processing Record 28 of Set 14 | osakarovka
# Processing Record 29 of Set 14 | vila velha
# Processing Record 30 of Set 14 | santa maria
# Processing Record 31 of Set 14 | qaqortoq
# Processing Record 32 of Set 14 | krasnoselkup
# Processing Record 33 of Set 14 | camacha
# Processing Record 34 of Set 14 | maragogi
# Processing Record 35 of Set 14 | anloga
# Processing Record 36 of Set 14 | uribia
# Processing Record 37 of Set 14 | bogense
# Processing Record 38 of Set 14 | ust-shonosha
# Processing Record 39 of Set 14 | poum
# Processing Record 40 of Set 14 | samarai
# Processing Record 41 of Set 14 | veraval
# Processing Record 42 of Set 14 | roald
# Processing Record 43 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 44 of Set 14 | sumenep
# Processing Record 45 of Set 14 | bilibino
# Processing Record 46 of Set 14 | salekhard
# Processing Record 47 of Set 14 | la ronge
# Processing Record 48 of Set 14 | gympie
# Processing Record 49 of Set 14 | pochutla
# Processing Record 50 of Set 14 | ballina
# Processing Record 1 of Set 15 | sopelana
# Processing Record 2 of Set 15 | beisfjord
# Processing Record 3 of Set 15 | nago
# Processing Record 4 of Set 15 | oussouye
# Processing Record 5 of Set 15 | ust-kuyga
# Processing Record 6 of Set 15 | kasongo-lunda
# Processing Record 7 of Set 15 | svetlaya
# Processing Record 8 of Set 15 | gjovik
# Processing Record 9 of Set 15 | pervomayskoye
# Processing Record 10 of Set 15 | zwedru
# Processing Record 11 of Set 15 | murray bridge
# Processing Record 12 of Set 15 | jacareacanga
# Processing Record 13 of Set 15 | asahikawa
# Processing Record 14 of Set 15 | sola
# Processing Record 15 of Set 15 | santo angelo
# Processing Record 16 of Set 15 | fairbanks
# Processing Record 17 of Set 15 | khudumelapye
# Processing Record 18 of Set 15 | charters towers
# Processing Record 19 of Set 15 | tamiahua
# Processing Record 20 of Set 15 | dongning
# Processing Record 21 of Set 15 | varhaug
# Processing Record 22 of Set 15 | kalia
# Processing Record 23 of Set 15 | ranong
# Processing Record 24 of Set 15 | saposoa
# Processing Record 25 of Set 15 | tuy hoa
# Processing Record 26 of Set 15 | gondar
# Processing Record 27 of Set 15 | tottori
# Processing Record 28 of Set 15 | diego de almagro
# Processing Record 29 of Set 15 | sumbe
# Processing Record 30 of Set 15 | katobu
# Processing Record 31 of Set 15 | arica
# Processing Record 32 of Set 15 | kobryn
# Processing Record 33 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 34 of Set 15 | tocopilla
# Processing Record 35 of Set 15 | buchanan
# Processing Record 36 of Set 15 | arrecife
# Processing Record 37 of Set 15 | yerbogachen
# Processing Record 38 of Set 15 | mendi
# Processing Record 39 of Set 15 | sinnamary
# Processing Record 40 of Set 15 | trabzon
# Processing Record 41 of Set 15 | boden
# Processing Record 42 of Set 15 | altay
# Processing Record 43 of Set 15 | oskaloosa
# Processing Record 44 of Set 15 | malakal
# Processing Record 45 of Set 15 | buriti dos lopes
# Processing Record 46 of Set 15 | mutoko
# Processing Record 47 of Set 15 | turayf
# Processing Record 48 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 49 of Set 15 | matagami
# Processing Record 50 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 1 of Set 16 | qingyuan
# Processing Record 2 of Set 16 | jiazi
# Processing Record 3 of Set 16 | batagay-alyta
# Processing Record 4 of Set 16 | talah
# City not found. Skipping...
# Processing Record 5 of Set 16 | magdagachi
# Processing Record 6 of Set 16 | baruun-urt
# Processing Record 7 of Set 16 | simmerath
# Processing Record 8 of Set 16 | puchezh
# Processing Record 9 of Set 16 | quatre cocos
# Processing Record 10 of Set 16 | fort nelson
# Processing Record 11 of Set 16 | ilebo
# Processing Record 12 of Set 16 | bukachacha
# Processing Record 13 of Set 16 | glendive
# Processing Record 14 of Set 16 | weston
# Processing Record 15 of Set 16 | kalmar
# Processing Record 16 of Set 16 | san isidro
# Processing Record 17 of Set 16 | mantua
# Processing Record 18 of Set 16 | rock springs
# Processing Record 19 of Set 16 | saravan
# Processing Record 20 of Set 16 | tezu
# Processing Record 21 of Set 16 | paragominas
# Processing Record 22 of Set 16 | la paz
# Processing Record 23 of Set 16 | kodinsk
# Processing Record 24 of Set 16 | monster
# Processing Record 25 of Set 16 | nizhnevartovsk
# Processing Record 26 of Set 16 | klyuchi
# Processing Record 27 of Set 16 | conceicao da barra
# Processing Record 28 of Set 16 | pulaski
# Processing Record 29 of Set 16 | lixourion
# Processing Record 30 of Set 16 | moquegua
# Processing Record 31 of Set 16 | hopelchen
# Processing Record 32 of Set 16 | cururupu
# Processing Record 33 of Set 16 | lucea
# Processing Record 34 of Set 16 | kargasok
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 723

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City      Lat       Lon  Max Temp  Humidity  Cloudiness  \
# 0             Amahai  -3.3333  128.9167     86.99        65          69
# 1            Ushuaia -54.8000  -68.3000     46.06        87           0
# 2         Hambantota   6.1241   81.1185     77.34       100          75
# 3             Torbay  47.6666  -52.7314     43.75        84         100
# 4        Tuktoyaktuk  69.4541 -133.0374     12.20        92         100
# 5      Sao Sebastiao -23.7600  -45.4097     73.62        90          97
# 6              Tiksi  71.6872  128.8694    -10.77        91         100
# 7            Salalah  17.0151   54.0924     71.69        56           0
# 8  Fortuna Foothills  32.6578 -114.4119     62.08        28           0
# 9        Deputatskiy  69.3000  139.9000    -27.92        98          72
#
#    Wind Speed Country Current Description
# 0        5.10      ID       Broken Clouds
# 1        4.61      AR           Clear Sky
# 2        1.14      LK       Broken Clouds
# 3       26.46      CA     Overcast Clouds
# 4       18.41      CA          Light Snow
# 5        5.41      BR     Overcast Clouds
# 6       12.77      RU     Overcast Clouds
# 7        2.30      OM           Clear Sky
# 8        6.91      US           Clear Sky
# 9        4.99      RU       Broken Clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lon', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_list = ["City", "Country", "Lat", "Lon", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_list]

# Display sample data
city_data_df.head()
# Out:
#           City Country      Lat       Lon  Max Temp  Humidity  Cloudiness  \
# 0       Amahai      ID  -3.3333  128.9167     86.99        65          69
# 1      Ushuaia      AR -54.8000  -68.3000     46.06        87           0
# 2   Hambantota      LK   6.1241   81.1185     77.34       100          75
# 3       Torbay      CA  47.6666  -52.7314     43.75        84         100
# 4  Tuktoyaktuk      CA  69.4541 -133.0374     12.20        92         100
#
#    Wind Speed Current Description
# 0        5.10       Broken Clouds
# 1        4.61           Clear Sky
# 2        1.14       Broken Clouds
# 3       26.46     Overcast Clouds
# 4       18.41          Light Snow

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lon                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
csv_file = ("WeatherPy_Database.csv")

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(csv_file, index_label = "City ID")
